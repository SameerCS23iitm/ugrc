# %%
import pandas as pd
DATA_DIR = "../train/"
benign = pd.read_csv(DATA_DIR + "1s_benign_flows.csv")
print(f"Total rows: {len(benign)}")
print(f"Unique src-dst pairs: {benign.groupby(['ip.src','ip.dst']).ngroups}")
print(f"\nRows per pair:")
print(benign.groupby(['ip.src','ip.dst']).size().sort_values(ascending=False))
# Out:
# Total rows: 25511
# Unique src-dst pairs: 12
#
# Rows per pair:
# ip.src       ip.dst
# 185.175.0.4  185.175.0.3    3715
# 185.175.0.8  185.175.0.3    3702
# 185.175.0.3  185.175.0.8    3584
#              185.175.0.4    3580
# 185.175.0.5  185.175.0.3    3572
# 185.175.0.3  185.175.0.5    3572
# 185.175.0.8  185.175.0.6     964
# 185.175.0.6  185.175.0.8     962
# 185.175.0.4  185.175.0.6     924
# 185.175.0.6  185.175.0.4     920
# 185.175.0.1  224.0.0.251      14
# 185.175.0.6  224.0.0.22        2
# dtype: int64

# %%
VALID_IPS = [
    "185.175.0.2", "185.175.0.3", "185.175.0.4",
    "185.175.0.5", "185.175.0.6", "185.175.0.7", "185.175.0.8"
]
cscada = pd.read_csv(DATA_DIR + "labeled_1s_cscada.csv")
cscada = cscada[cscada["ip.src"].isin(VALID_IPS) & cscada["ip.dst"].isin(VALID_IPS)]
print(f"Total rows: {len(cscada)}")
print(f"Unique src-dst pairs: {cscada.groupby(['ip.src','ip.dst']).ngroups}")
print(f"\nRows per pair:")
print(cscada.groupby(["ip.src","ip.dst"]).size().sort_values(ascending=False))
# Out:
# Total rows: 48086
# Unique src-dst pairs: 10
#
# Rows per pair:
# ip.src       ip.dst
# 185.175.0.4  185.175.0.3    7050
# 185.175.0.8  185.175.0.3    7037
# 185.175.0.3  185.175.0.5    7029
# 185.175.0.5  185.175.0.3    7028
# 185.175.0.3  185.175.0.4    6776
#              185.175.0.8    6772
# 185.175.0.8  185.175.0.6    1677
# 185.175.0.6  185.175.0.8    1619
# 185.175.0.4  185.175.0.6    1586
# 185.175.0.6  185.175.0.4    1512
# dtype: int64
